# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Load the run data (DIC-C2DH-HeLa)

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/without"):
    df = pd.read_csv("data/dic/without/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0 and val < 999:
            combined[idx].append(val)



dic_baseline_no_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = dic_baseline_no_embeddings.index(max(dic_baseline_no_embeddings))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.985492911308935, 0.975601714474118, 0.987800857237059, 0.9858226178700956, 0.9851632047477744, 0.9891196834817012, 0.9897790966040224, 0.98846027035938]
# 0.9859050445103856
# 1.7793881546313842e-05

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/original_maester_embeddings"):
    df = pd.read_csv("data/dic/original_maester_embeddings/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_original_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = dic_original_maester_embeddings.index(max(dic_original_maester_embeddings))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9891196834817012, 0.9818661391361688, 0.9841740850642928, 0.9785690735245632, 0.9788987800857236, 0.9765908341575996, 0.9792284866468842, 0.975601714474118]
# 0.9805060995713815
# 1.7105973754575044e-05

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/mma_maester_embeddings/"):
    df = pd.read_csv("data/dic/mma_maester_embeddings/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_mma_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = dic_mma_maester_embeddings.index(max([x for x in dic_mma_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.987141444114738, 0.9897790966040224, 0.9835146719419716, 0.984833498186614, 0.9868117375535772, 0.9841740850642928, 0.9835146719419716, 0.9861523244312562]
# 0.9857401912298055
# 4.0968730708008184e-06

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/additional_vit_b_____DIC-C2DH-HeLa"):
    df = pd.read_csv("data/dic/additional_vit_b_____DIC-C2DH-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_vit_b_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = dic_vit_b_maester_embeddings.index(max([x for x in dic_vit_b_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9904385097263436, 0.9917573359709858, 0.98846027035938, 0.9904385097263436, 0.9904385097263436, 0.9861523244312562, 0.9904385097263436, 0.9792284866468842]
# 0.988419057039235
# 1.4632902779829826e-05

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/mma_additional_vit_b_____DIC-C2DH-HeLa"):
    df = pd.read_csv("data/dic/mma_additional_vit_b_____DIC-C2DH-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

mma_dic_vit_b_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = mma_dic_vit_b_maester_embeddings.index(max([x for x in mma_dic_vit_b_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.990768216287504, 0.9897790966040224, 0.990108803165183, 0.9835146719419716, 0.9917573359709858, 0.987141444114738, 0.9891196834817012, 0.990108803165183]
# 0.9890372568414111
# 5.917705546712205e-06

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/additional_vit_b_lm_____DIC-C2DH-HeLa"):
    df = pd.read_csv("data/dic/additional_vit_b_lm_____DIC-C2DH-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_vit_b_lm_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = dic_vit_b_lm_maester_embeddings.index(max([x for x in dic_vit_b_lm_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.98846027035938, 0.984833498186614, 0.984833498186614, 0.984833498186614, 0.98846027035938, 0.9874711506758984, 0.9874711506758984, 0.98846027035938]
# 0.9868529508737223
# 2.5936671555190485e-06

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/mma_additional_vit_b_lm_____DIC-C2DH-HeLa"):
    df = pd.read_csv("data/dic/mma_additional_vit_b_lm_____DIC-C2DH-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

mma_dic_vit_b_lm_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = mma_dic_vit_b_lm_maester_embeddings.index(max([x for x in mma_dic_vit_b_lm_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9904385097263436, 0.9897790966040224, 0.9874711506758984, 0.9910979228486648, 0.9891196834817012, 0.9917573359709858, 0.98846027035938, 0.9904385097263436]
# 0.9898203099241675
# 1.7511924278590341e-06

# %% [markdown]
# #### Load the run data (Fluo-N2DL-HeLa)

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/without"):
    df = pd.read_csv("data/fluo/without/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0 and val < 999:
            combined[idx].append(val)

fluo_baseline_no_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = fluo_baseline_no_embeddings.index(max([x for x in fluo_baseline_no_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9924639754185208, 0.9916560712015258, 0.991947446492901, 0.9916958041958042, 0.9921726001271456, 0.9923977537613902, 0.9921726001271456, 0.9935632549268912]
# 0.9922586882814155
# 3.193819724009425e-07

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/original_maester_embeddings"):
    df = pd.read_csv("data/fluo/original_maester_embeddings/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_original_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = fluo_original_maester_embeddings.index(max([x for x in fluo_original_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9946228014409833, 0.9942254714981988, 0.994331426149608, 0.9947287560923924, 0.993801652892562, 0.993271879635516, 0.9944506251324432, 0.9956426149607968]
# 0.9943844034753125
# 4.2103340890038684e-07

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/mma_maester_embeddings"):
    df = pd.read_csv("data/fluo/mma_maester_embeddings/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_mma_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = fluo_mma_maester_embeddings.index(max([x for x in fluo_mma_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9936692095783004, 0.9940268065268064, 0.9942254714981988, 0.9929407713498624, 0.99256993006993, 0.9930334816698452, 0.994516846789574, 0.9932453909726636]
# 0.9935284885568976
# 4.150227962967697e-07

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/additional_vit_b_____Fluo-N2DL-HeLa"):
    df = pd.read_csv("data/fluo/additional_vit_b_____Fluo-N2DL-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_vit_b_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = fluo_vit_b_maester_embeddings.index(max([x for x in fluo_vit_b_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9932056579783852, 0.9931261919898284, 0.9916163382072471, 0.9924374867556686, 0.9916030938758212, 0.9916560712015258, 0.9932321466412376, 0.9923712650985378]
# 0.9924060314685315
# 4.5918284657934186e-07

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/mma_additional_vit_b_____Fluo-N2DL-HeLa"):
    df = pd.read_csv("data/fluo/mma_additional_vit_b_____Fluo-N2DL-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

mma_fluo_vit_b_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = mma_fluo_vit_b_maester_embeddings.index(max([x for x in mma_fluo_vit_b_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9918150031786396, 0.9933116126297944, 0.9922785547785548, 0.9923580207671115, 0.991669315532952, 0.9920136681500318, 0.9926361517270608, 0.9921063784700148]
# 0.9922735881542699
# 2.3588296967886497e-07

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/additional_vit_b_lm_____Fluo-N2DL-HeLa"):
    df = pd.read_csv("data/fluo/additional_vit_b_lm_____Fluo-N2DL-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_vit_b_lm_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = fluo_vit_b_lm_maester_embeddings.index(max([x for x in fluo_vit_b_lm_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.993642720915448, 0.992649396058487, 0.992212333121424, 0.9928745496927316, 0.9933248569612206, 0.9928348166984532, 0.9930732146641238, 0.9935632549268912]
# 0.9930218928798474
# 2.0297123409094127e-07

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/mma_additional_vit_b_lm_____Fluo-N2DL-HeLa"):
    df = pd.read_csv("data/fluo/mma_additional_vit_b_lm_____Fluo-N2DL-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

mma_fluo_vit_b_lm_maester_embeddings = [sum(x) / len(x) if x else None for x in combined]

iloc = mma_fluo_vit_b_lm_maester_embeddings.index(max([x for x in mma_fluo_vit_b_lm_maester_embeddings if x is not None]))
print(combined[iloc])
mean = np.mean(combined[iloc])
variance = np.var(combined[iloc])
print(mean)
print(variance)
# Out:
# [0.9931924136469592, 0.9924242424242424, 0.9935632549268912, 0.9923977537613902, 0.9935102776011868, 0.99325863530409, 0.9932189023098114, 0.9924904640813732]
# 0.993006993006993
# 2.1036321867464653e-07

# %%
max(dic_original_maester_embeddings[:100])
# Out:
# 0.9805060995713815

# %%
import matplotlib
plt.style.use("seaborn-v0_8-muted")
def set_size(width_pt=472.31595, fraction=1, subplots=(1, 1)):
    """Set figure dimensions nicely

    Parameters
    ----------
    width_pt: float
            Document width in points
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy
    subplots: array-like, optional
            The number of rows and columns of subplots.
    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5 ** .5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return fig_width_in, fig_height_in

# Colormap with University colors
colors = ["white", "#005f9b", "#153268"]
nodes = [0.0, 0.8, 1.0]
unimap = matplotlib.colors.LinearSegmentedColormap.from_list("unimap", list(zip(nodes, colors)))
unimap_r = unimap.reversed()
try:
    matplotlib.colormaps.register(cmap=unimap)
    matplotlib.colormaps.register(cmap=unimap_r)
except ValueError:
    pass

# LaTeX text renderer
plt.rcParams.update({
    "font.family": "serif",  # use serif/main font for text elements
    "font.serif": "Computer Modern Roman",
    "text.usetex": True,  # use inline math for ticks
    "text.latex.preamble": r"\usepackage{amsmath}",
    "pgf.rcfonts": False,  # don't setup fonts from rc parameters
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 10,
    "font.size": 10.95,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    # Cmap
    "image.cmap": "unimap"
})
 
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=set_size(fraction=1, subplots=(1.2, 1)), sharex=True)

ax1.hist(np.random.poisson(7, 10000), bins=200)
ax2.hist(np.random.normal(1, 1, 10000), bins=200)

plt.tight_layout()
plt.show()
fig.savefig('style.pdf', format='pdf', bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Plot the data

# %% [markdown]
# #### MAESTER

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

#ax.flat[0].plot(dic_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='dic baseline / no emb.', color='black', linestyle='dashed')

#ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[0].plot(dic_original_maester_embeddings[:100], label='dic_original_maester_embeddings')

#ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[0].plot(dic_mma_maester_embeddings[:100], label='dic_mma_maester_embeddings')


ax.flat[0].set_ylabel("Linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()
ax.flat[0].set_title("DIC-C2DH-HeLa")

ax.flat[0].set_ylim(0.9, 1.0)
ax.flat[0].set_xlim(0, 20)

#ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='fluo baseline / no emb.', color='black', linestyle='dashed')

#ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='fluo_original_maester_embeddings')

#ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[1].plot(fluo_mma_maester_embeddings[:100], label='fluo_mma_maester_embeddings')

ax.flat[1].set_ylabel("Linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()
ax.flat[1].set_title("Fluo-N2DL-HeLa")

ax.flat[1].set_ylim(0.97, 1.0)
ax.flat[1].set_xlim(0, 20)

plt.savefig("fluo_dic_draft.png")

# %% [markdown]
# #### vit_b / vit_b_lm

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

#ax.flat[0].plot(dic_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='dic baseline / no emb.', color='black', linestyle='dashed')

#ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='dic_vit_b_maester_embeddings')

#ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[0].plot(dic_vit_b_lm_maester_embeddings[:100], label='dic_vit_b_lm_maester_embeddings')


ax.flat[0].set_ylabel("Linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()
ax.flat[0].set_title("DIC-C2DH-HeLa")

ax.flat[0].set_ylim(0.9, 1.0)
ax.flat[0].set_xlim(0, 20)

#ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='fluo baseline / no emb.', color='black', linestyle='dashed')

#ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='fluo_vit_b_maester_embeddings')

#ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[1].plot(fluo_vit_b_lm_maester_embeddings[:100], label='fluo_vit_b_lm_maester_embeddings')

ax.flat[1].set_ylabel("Linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()
ax.flat[1].set_title("Fluo-N2DL-HeLa")

ax.flat[1].set_ylim(0.97, 1.0)
ax.flat[1].set_xlim(0, 20)

plt.savefig("fluo_dic_draft.pdf")

# %% [markdown]
# #### vit_b / vit_b_lm vs. old generalist

# %%
general_2d_fluo = 0.990371
general_2d_dic = 0.981536

# %%
pip install tol-colors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tol_colors as tc
from matplotlib.ticker import FuncFormatter, MaxNLocator

# %% [markdown]
# ##### microSAM Centroid

# %%
from matplotlib import pyplot as plt
from cycler import cycler

fig, ax = plt.subplots(1,2, figsize=(12,4))

#ax.flat[0].plot(dic_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[0].axhline(general_2d_dic, label='Trackastra (pretrained)', color=tc.high_contrast[1])

#ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b] (centroid)', color=tc.high_contrast[2])

#ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[0].plot(dic_vit_b_lm_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b\_lm] (centroid)', color=tc.high_contrast[3])


ax.flat[0].set_ylabel("DIC-C2DH-HeLa linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()
#ax.flat[0].set_title("DIC-C2DH-HeLa")

ax.flat[0].set_ylim(0.97, 0.999)
ax.flat[0].set_xlim(0, 20)
ax.flat[0].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[0].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

#ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[1].axhline(general_2d_fluo, label='Trackastra (pretrained)', color=tc.high_contrast[1])
#ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b] (centroid)', color=tc.high_contrast[2])

#ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[1].plot(fluo_vit_b_lm_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b\_lm] (centroid)', color=tc.high_contrast[3])

ax.flat[1].set_ylabel("Fluo-N2DL-HeLa linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()
#ax.flat[1].set_title("Fluo-N2DL-HeLa")

ax.flat[1].set_ylim(0.97, 0.995)
ax.flat[1].set_xlim(0, 20)
ax.flat[1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[1].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

plt.savefig("micro_sam_centroid.pdf")

# %% [markdown]
# ##### microSAM MMA

# %%
from matplotlib import pyplot as plt
from cycler import cycler

fig, ax = plt.subplots(1,2, figsize=(12,4))

#ax.flat[0].plot(dic_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[0].axhline(general_2d_dic, label='Trackastra (pretrained)', color=tc.high_contrast[1])

#ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b] (MMA)', color=tc.high_contrast[2])

#ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[0].plot(mma_dic_vit_b_lm_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b\_lm] (MMA)', color=tc.high_contrast[3])


ax.flat[0].set_ylabel("DIC-C2DH-HeLa linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()
#ax.flat[0].set_title("DIC-C2DH-HeLa")

ax.flat[0].set_ylim(0.97, 0.995)
ax.flat[0].set_xlim(0, 20)
ax.flat[0].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[0].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

#ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[1].axhline(general_2d_fluo, label='Trackastra (pretrained)', color=tc.high_contrast[1])
#ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b] (MMA)', color=tc.high_contrast[2])

#ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label='mma_vit_b')
ax.flat[1].plot(mma_fluo_vit_b_lm_maester_embeddings[:100], label=r'Trackastra + $\mu$SAM[vit\_b\_lm] (MMA)', color=tc.high_contrast[3])

ax.flat[1].set_ylabel("Fluo-N2DL-HeLa linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()
#ax.flat[1].set_title("Fluo-N2DL-HeLa")

ax.flat[1].set_ylim(0.97, 0.995)
ax.flat[1].set_xlim(0, 20)
ax.flat[1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[1].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

plt.savefig("micro_sam_mma.pdf")

# %% [markdown]
# #### MAESTER vs. old generalist

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

#ax.flat[0].plot(dic_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[0].axhline(general_2d_dic, label='Trackastra (pretrained)', color=tc.high_contrast[1])

#ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[0].plot(dic_original_maester_embeddings[:100], label='Trackastra + MAESTER (centroid)', color=tc.high_contrast[2])

#ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label='mma_vit_b')
#ax.flat[0].plot(dic_mma_maester_embeddings[:100], label='dic_mma_maester_embeddings', color=tc.high_contrast[3])


ax.flat[0].set_ylabel("DIC-C2DH-HeLa linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()
#ax.flat[0].set_title("DIC-C2DH-HeLa")

ax.flat[0].set_ylim(0.9, .995)
ax.flat[0].set_xlim(0, 20)
ax.flat[0].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[0].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

#ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[1].axhline(general_2d_fluo, label='Trackastra (pretrained)', color=tc.high_contrast[1])

#ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='Trackastra + MAESTER (centroid)', color=tc.high_contrast[2])

#ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label='mma_vit_b')
#ax.flat[1].plot(fluo_mma_maester_embeddings[:100], label='fluo_mma_maester_embeddings', color=tc.high_contrast[3])

ax.flat[1].set_ylabel("Fluo-N2DL-HeLa linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()
#ax.flat[1].set_title("Fluo-N2DL-HeLa")

ax.flat[1].set_ylim(0.97, 0.995)
ax.flat[1].set_xlim(0, 20)
ax.flat[1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[1].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

plt.savefig("maester_centroid.pdf")

# %% [markdown]
# ### Max. values

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

#ax.flat[0].plot(dic_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[0].axhline(general_2d_dic, label='Trackastra (pretrained)', color=tc.high_contrast[1])

#ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[0].plot(dic_mma_maester_embeddings[:100], label='Trackastra + MAESTER (MMA)', color=tc.high_contrast[2])

#ax.flat[0].plot(mma_dic_vit_b_maester_embeddings[:100], label='mma_vit_b')
#ax.flat[0].plot(dic_mma_maester_embeddings[:100], label='dic_mma_maester_embeddings', color=tc.high_contrast[3])


ax.flat[0].set_ylabel("DIC-C2DH-HeLa linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()
#ax.flat[0].set_title("DIC-C2DH-HeLa")

ax.flat[0].set_ylim(0.9, .995)
ax.flat[0].set_xlim(0, 20)
ax.flat[0].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[0].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

#ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='centroid_maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='Trackastra (re-trained)', color=tc.high_contrast[0], linestyle='dashed')

ax.flat[1].axhline(general_2d_fluo, label='Trackastra (pretrained)', color=tc.high_contrast[1])

#ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='centroid_vit_b')
ax.flat[1].plot(fluo_mma_maester_embeddings[:100], label='Trackastra + MAESTER (MMA)', color=tc.high_contrast[2])
fluo_mma_maester_embeddings
#ax.flat[1].plot(mma_fluo_vit_b_maester_embeddings[:100], label='mma_vit_b')
#ax.flat[1].plot(fluo_mma_maester_embeddings[:100], label='fluo_mma_maester_embeddings', color=tc.high_contrast[3])

ax.flat[1].set_ylabel("Fluo-N2DL-HeLa linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()
#ax.flat[1].set_title("Fluo-N2DL-HeLa")

ax.flat[1].set_ylim(0.97, .995)
ax.flat[1].set_xlim(0, 20)
ax.flat[1].xaxis.set_major_locator(MaxNLocator(integer=True))
ax.flat[1].xaxis.set_major_formatter(FuncFormatter(lambda x, pos: int(x + 1)))

plt.savefig("maester_mma.pdf")
