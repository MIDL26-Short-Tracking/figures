# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

cmap = mpl.cm.get_cmap('Set2')
num_colors = 8

colors = [cmap(i / num_colors) for i in range(num_colors)]
ca = colors[0]
cb = colors[2]
# Out:
# /tmp/ipykernel_64070/1317914952.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = mpl.cm.get_cmap('Set2')

# %%
plt.style.use("seaborn-v0_8-muted")
def set_size(width_pt=472.31595, fraction=1, subplots=(1, 1)):
    """Set figure dimensions nicely

    Parameters
    ----------
    width_pt: float
            Document width in points
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy
    subplots: array-like, optional
            The number of rows and columns of subplots.
    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5 ** .5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return fig_width_in, fig_height_in

# Colormap with University colors
colors = ["white", "#005f9b", "#153268"]
nodes = [0.0, 0.8, 1.0]
unimap = matplotlib.colors.LinearSegmentedColormap.from_list("unimap", list(zip(nodes, colors)))
unimap_r = unimap.reversed()
try:
    matplotlib.colormaps.register(cmap=unimap)
    matplotlib.colormaps.register(cmap=unimap_r)
except ValueError:
    pass

# LaTeX text renderer
plt.rcParams.update({
    "font.family": "serif",  # use serif/main font for text elements
    "font.serif": "Computer Modern Roman",
    "text.usetex": True,  # use inline math for ticks
    "text.latex.preamble": r"\usepackage{amsmath}",
    "pgf.rcfonts": False,  # don't setup fonts from rc parameters
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 10,
    "font.size": 10.95,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    # Cmap
    "image.cmap": "unimap"
})
 
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=set_size(fraction=1, subplots=(1.2, 1)), sharex=True)

ax1.hist(np.random.poisson(7, 10000), bins=200)
ax2.hist(np.random.normal(1, 1, 10000), bins=200)

plt.tight_layout()
plt.show()
fig.savefig('style.pdf', format='pdf', bbox_inches='tight', dpi=300)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from collections import defaultdict

# %%
meanlists_1x = {}
treatment_compute_max_map_1x = defaultdict(list)

for checkpoint in os.listdir("data/1x/"):
    dlist = []

    if os.path.exists(f"data/1x/{checkpoint}/witheffects/"):
        for csvfile in os.listdir(f"data/1x/{checkpoint}/witheffects/"):
            data = pd.read_csv(f"data/1x/{checkpoint}/witheffects/{csvfile}")
        
            dlist.append(data["LNK"].to_list())
    
            treatment_compute_max_map_1x[int(checkpoint)].append(max(data["LNK"].to_list()))

        meanlist = []
        for idx in range(max([len(x) for x in dlist])):
            i = 0
            summe = 0
            for dl in dlist:
                try:
                    summe += dl[idx]
                    i += 1
                except:
                    pass
            meanlist.append(summe / i)
        meanlists_1x[checkpoint] = meanlist

# %%
meanlists_2x = {}
treatment_compute_max_map_2x = defaultdict(list)

for checkpoint in os.listdir("data/2x/"):
    dlist = []

    if os.path.exists(f"data/2x/{checkpoint}/witheffects/"):
        for csvfile in os.listdir(f"data/2x/{checkpoint}/witheffects/"):
            data = pd.read_csv(f"data/2x/{checkpoint}/witheffects/{csvfile}")
        
            dlist.append(data["LNK"].to_list())
    
            treatment_compute_max_map_2x[int(checkpoint)].append(max(data["LNK"].to_list()))

        meanlist = []
        for idx in range(max([len(x) for x in dlist])):
            i = 0
            summe = 0
            for dl in dlist:
                try:
                    summe += dl[idx]
                    i += 1
                except:
                    pass
            meanlist.append(summe / i)
        meanlists_2x[checkpoint] = meanlist

# %%
meanlists_3x = {}
treatment_compute_max_map_3x = defaultdict(list)

for checkpoint in os.listdir("data/3x/"):
    dlist = []

    if os.path.exists(f"data/3x/{checkpoint}/witheffects/"):
        for csvfile in os.listdir(f"data/3x/{checkpoint}/witheffects/"):
            data = pd.read_csv(f"data/3x/{checkpoint}/witheffects/{csvfile}")
        
            dlist.append(data["LNK"].to_list())
    
            treatment_compute_max_map_3x[int(checkpoint)].append(max(data["LNK"].to_list()))

        meanlist = []
        for idx in range(max([len(x) for x in dlist])):
            i = 0
            summe = 0
            for dl in dlist:
                try:
                    summe += dl[idx]
                    i += 1
                except:
                    pass
            meanlist.append(summe / i)
        meanlists_3x[checkpoint] = meanlist

# %%
meanlists_4x = {}
treatment_compute_max_map_4x = defaultdict(list)

for checkpoint in os.listdir("data/4x/"):
    dlist = []

    if os.path.exists(f"data/4x/{checkpoint}/witheffects/"):
        for csvfile in os.listdir(f"data/4x/{checkpoint}/witheffects/"):
            data = pd.read_csv(f"data/4x/{checkpoint}/witheffects/{csvfile}")
        
            dlist.append(data["LNK"].to_list())
    
            treatment_compute_max_map_4x[int(checkpoint)].append(max(data["LNK"].to_list()))

        meanlist = []
        for idx in range(max([len(x) for x in dlist])):
            i = 0
            summe = 0
            for dl in dlist:
                try:
                    summe += dl[idx]
                    i += 1
                except:
                    pass
            meanlist.append(summe / i)
        meanlists_4x[checkpoint] = meanlist

# %%
import tol_colors as tc

# %%
sorted(treatment_compute_max_map_3x.keys())
# Out:
# [49, 1399, 2399, 4399, 6399, 8399, 10399, 12399, 14399, 16399, 17599]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
means = []

for k, l in treatment_compute_max_map.items():
    for v in l:
        x.append(k)
        y.append(v)
    means.append(sum(l) / len(l))

x = np.asarray(x, dtype=float)
y = np.asarray(y, dtype=float)

fig, ax = plt.subplots(4, 1, figsize=set_size(fraction=1, subplots=(4.8, 2)))

bplot = ax.flat[0].boxplot([treatment_compute_max_map_1x[k] for k in sorted(treatment_compute_max_map_1x.keys())],
           positions=list(sorted(treatment_compute_max_map_1x.keys())),
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor(tc.vibrant[0])
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')
    

bplot = ax.flat[1].boxplot([treatment_compute_max_map_2x[k] for k in sorted(treatment_compute_max_map_2x.keys())],
           positions=list(sorted(treatment_compute_max_map_2x.keys())),
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor(tc.vibrant[1])
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')


bplot = ax.flat[2].boxplot([treatment_compute_max_map_3x[k] for k in sorted(treatment_compute_max_map_3x.keys())],
           positions=[x+300 for x in list(sorted(treatment_compute_max_map_3x.keys()))],
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor(tc.vibrant[2])
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')


bplot = ax.flat[3].boxplot([treatment_compute_max_map_4x[k] for k in sorted(treatment_compute_max_map_4x.keys())],
           positions=[x+600 for x in list(sorted(treatment_compute_max_map_4x.keys()))],
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor(tc.vibrant[3])
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')

for a in ax:
    a.set_ylim(0.993, 0.996)
    a.set_xticks(np.arange(0, 18001, 2000))   # or whatever spacing you want

ax.flat[0].set_xlim(0, 18000)
ax.flat[0].set_autoscale_on(False)
ax.flat[1].set_xlim(0, 18000)
ax.flat[1].set_autoscale_on(False)
ax.flat[2].set_xlim(0, 18000)
ax.flat[2].set_autoscale_on(False)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       5 y = []
#       6 means = []
# ----> 8 for k, l in treatment_compute_max_map.items():
#       9     for v in l:
#      10         x.append(k)
#
# NameError: name 'treatment_compute_max_map' is not defined

# %%
#fig, ax = plt.subplots(1, 1, figsize=set_size(fraction=1, subplots=(1.2, 2)))
fig, ax = plt.subplots(1, 1, figsize=set_size(fraction=1, subplots=(1, 1.35)))

ax.plot(sorted(treatment_compute_max_map_1x.keys()),
        [sum(treatment_compute_max_map_1x[k])/len(treatment_compute_max_map_1x[k]) if len(treatment_compute_max_map_1x[k]) > 0 else None for k in sorted(treatment_compute_max_map_1x.keys())],
        label='1x data',
        color=tc.bright[1],
        marker='o', linewidth=1.4, markersize=3.5)

ax.plot(sorted(treatment_compute_max_map_2x.keys()),
        [sum(treatment_compute_max_map_2x[k])/len(treatment_compute_max_map_2x[k]) for k in sorted(treatment_compute_max_map_2x.keys())],
        label='2x data',
        color=tc.bright[2],
        marker='o', linewidth=1.4, markersize=3.5)

ax.plot(sorted(treatment_compute_max_map_3x.keys()),
        [sum(treatment_compute_max_map_3x[k])/len(treatment_compute_max_map_3x[k]) for k in sorted(treatment_compute_max_map_3x.keys())],
        label='3x data',
        color=tc.bright[3],
        marker='o', linewidth=1.4, markersize=3.5)

ax.plot(sorted(treatment_compute_max_map_4x.keys()),
        [sum(treatment_compute_max_map_4x[k])/len(treatment_compute_max_map_4x[k]) for k in sorted(treatment_compute_max_map_4x.keys())],
        label='4x data',
        color=tc.bright[4],
        marker='o', linewidth=1.4, markersize=3.5)

ax.set_xlabel("Pre-training compute (steps)")
ax.set_ylabel("Linking Performance (LNK)")

ax.set_ylim(0.9933, 0.9955)

plt.legend(loc='lower center')
plt.tight_layout()

plt.savefig("FINAL_c_pretrain compute_data.pdf")

# %%
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
means = []

for k, l in treatment_compute_max_map.items():
    for v in l:
        x.append(k)
        y.append(v)
    means.append(sum(l) / len(l))

x = np.asarray(x, dtype=float)
y = np.asarray(y, dtype=float)

fig, ax = plt.subplots(3, 1, figsize=set_size(fraction=1, subplots=(3.6, 2)))

bplot = ax.flat[0].boxplot([treatment_compute_max_map_2x[k] for k in sorted(treatment_compute_max_map_2x.keys())],
           positions=list(sorted(treatment_compute_max_map_2x.keys())),
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor('red')
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')


bplot = ax.flat[1].boxplot([treatment_compute_max_map_3x[k] for k in sorted(treatment_compute_max_map_3x.keys())],
           positions=[x+300 for x in list(sorted(treatment_compute_max_map_3x.keys()))],
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor('green')
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')


bplot = ax.flat[2].boxplot([treatment_compute_max_map_4x[k] for k in sorted(treatment_compute_max_map_4x.keys())],
           positions=[x+600 for x in list(sorted(treatment_compute_max_map_4x.keys()))],
           widths=300,
           patch_artist=True,
           manage_ticks=False);

for box in bplot['boxes']:
    box.set_facecolor('blue')
    box.set_edgecolor('black')

for median in bplot['medians']:
    median.set_color('black')

for whisker in bplot['whiskers']:
    whisker.set_color('black')

for cap in bplot['caps']:
    cap.set_color('black')

for flier in bplot['fliers']:
    flier.set_markeredgecolor('black')

for a in ax:
    a.set_ylim(0.993, 0.996)
    a.set_xticks(np.arange(0, 18001, 2000))   # or whatever spacing you want

ax.flat[0].set_xlim(0, 18000)
ax.flat[0].set_autoscale_on(False)
ax.flat[1].set_xlim(0, 18000)
ax.flat[1].set_autoscale_on(False)
ax.flat[2].set_xlim(0, 18000)
ax.flat[2].set_autoscale_on(False)

plt.tight_layout()
