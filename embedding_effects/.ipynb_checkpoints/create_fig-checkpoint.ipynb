# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the run data (DIC-C2DH-HeLa)

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/without"):
    df = pd.read_csv("data/dic/without/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0 and val < 999:
            combined[idx].append(val)

dic_baseline_no_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/original_maester_embeddings"):
    df = pd.read_csv("data/dic/original_maester_embeddings/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_original_maester_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/additional_vit_b_____DIC-C2DH-HeLa"):
    df = pd.read_csv("data/dic/additional_vit_b_____DIC-C2DH-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_vit_b_maester_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/dic/additional_vit_b_lm_____DIC-C2DH-HeLa"):
    df = pd.read_csv("data/dic/additional_vit_b_lm_____DIC-C2DH-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

dic_vit_b_lm_maester_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %% [markdown]
# #### Load the run data (Fluo-N2DL-HeLa)

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/without"):
    df = pd.read_csv("data/fluo/without/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0 and val < 999:
            combined[idx].append(val)

fluo_baseline_no_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/original_maester_embeddings"):
    df = pd.read_csv("data/fluo/original_maester_embeddings/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_original_maester_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/additional_vit_b_____Fluo-N2DL-HeLa"):
    df = pd.read_csv("data/fluo/additional_vit_b_____Fluo-N2DL-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_vit_b_maester_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
combined = [list() for _ in range(300)]

for fname in os.listdir("data/fluo/additional_vit_b_lm_____Fluo-N2DL-HeLa"):
    df = pd.read_csv("data/fluo/additional_vit_b_lm_____Fluo-N2DL-HeLa/"+fname)

    l = df['LNK'].to_list()

    
    for idx, val in enumerate(l):
        if val > 0:
            combined[idx].append(val)

fluo_vit_b_lm_maester_embeddings = [sum(x)/(len(x)+1) for x in combined]

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))

ax.flat[0].plot(dic_original_maester_embeddings[:100], label='maester')
ax.flat[0].plot(dic_baseline_no_embeddings[:100], label='baseline')

ax.flat[0].plot(dic_vit_b_maester_embeddings[:100], label='vit_b')
ax.flat[0].plot(dic_vit_b_lm_maester_embeddings[:100], label='vit_b_lm')

ax.flat[0].set_ylabel("Linking performance (LNK)")
ax.flat[0].set_xlabel("Training epochs")

ax.flat[0].legend()

ax.flat[1].plot(fluo_original_maester_embeddings[:100], label='maester')
ax.flat[1].plot(fluo_baseline_no_embeddings[:100], label='baseline')

ax.flat[1].plot(fluo_vit_b_maester_embeddings[:100], label='vit_b')
ax.flat[1].plot(fluo_vit_b_lm_maester_embeddings[:100], label='vit_b_lm')

ax.flat[1].set_ylabel("Linking performance (LNK)")
ax.flat[1].set_xlabel("Training epochs")

ax.flat[1].legend()

plt.savefig("fluo_dic_draft.pdf")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.plot([a-b for a,b in zip(original_maester_embeddings, baseline_no_embeddings)][:100], linewidth=1)
plt.plot([a-b for a,b in zip(vit_b_maester_embeddings, baseline_no_embeddings)][:100], linewidth=0.6)
plt.plot([a-b for a,b in zip(vit_b_lm_maester_embeddings, baseline_no_embeddings)][:100], linewidth=0.6)
